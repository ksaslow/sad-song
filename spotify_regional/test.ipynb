# %%
import os
import glob
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('_all_spotify_data.csv')
data
# Out:
#      Unnamed: 0  Position                            Track Name  \
# 0             0         1       WAP (feat. Megan Thee Stallion)
# 1             1         2                Mood (feat. iann dior)
# 2             2         3  Laugh Now Cry Later (feat. Lil Durk)
# 3             3         4          ROCKSTAR (feat. Roddy Ricch)
# 4             4         5                        Xola Moya Wam'
# ..          ...       ...                                   ...
# 445         445         1                               WANNABE
# 446         446         2              Intentions (feat. Quavo)
# 447         447         3                          Dance Monkey
# 448         448         4                       Don't Start Now
# 449         449         5                                Say So
#
#              Artist  Streams  \
# 0           Cardi B    15520
# 1          24kGoldn    13500
# 2             Drake    11555
# 3            DaBaby     9901
# 4    Nomcebo Zikode     9789
# ...
