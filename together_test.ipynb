# %%
import os
import glob
import pandas as pd
import numpy as np 
import datetime 
import requests
import re
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
oxford = pd.read_csv('normalised_oxford.csv')
oxford_df = pd.DataFrame(oxford)

# %%
spotify = pd.read_csv('normalised_spotify.csv')
spotify_df = pd.DataFrame(spotify)

# %%
ox_spot = pd.merge(oxford_df, spotify_df, on=['CountryName', 'Year_Month'])
ox_spot
# Out:
#     Unnamed: 0_x   CountryName Year_Month  PolicyValue  Unnamed: 0_y  \
# 0              0        Brazil    2020-02     0.000000             0
# 1              1        Brazil    2020-03     1.000000             1
# 2              2        Brazil    2020-04     1.000000             2
# 3              3        Brazil    2020-05     1.838710             3
# 4              4        Brazil    2020-06     2.000000             4
# 5              5        Brazil    2020-07     2.000000             5
# 6              6        Brazil    2020-08     2.225806             6
# 7              7        Brazil    2020-09     0.000000             7
# 8              8         Italy    2020-02     0.413793             8
# 9              9         Italy    2020-03     2.225806             9
# 10            10         Italy    2020-04     2.300000            10
# 11            11         Italy    2020-05     2.000000            11
# 12            12         Italy    2020-06     0.866667            12
# 13            13         Italy    2020-07     0.000000            13
# 14            14         Italy    2020-08     0.000000            14
# 15            15         Italy    2020-09     0.000000            15
# 16            24  South Africa    2020-02     0.000000            24
# 17            25  South Africa    2020-03     0.322581            25
# 18            26  South Africa    2020-04     2.000000            26
# 19            27  South Africa    2020-05     2.000000            27
# 20            28  South Africa    2020-06     1.000000            28
# 21            29  South Africa    2020-07     1.580645            29
# 22            30  South Africa    2020-08     0.000000            30
# 23            31  South Africa    2020-09     0.000000            31
# 24            32           USA    2020-02     0.000000            32
# 25            33           USA    2020-03     1.032258            33
# 26            34           USA    2020-04     2.000000            34
# 27            35           USA    2020-05     2.000000            35
# 28            36           USA    2020-06     2.000000            36
# 29            37           USA    2020-07     1.612903            37
# 30            38           USA    2020-08     1.000000            38
# 31            39           USA    2020-09     1.000000            39
#
#     Happy Index
# 0      0.302712
# 1      0.357956
# 2      0.373075
# 3      0.362001
# 4      0.362001
# 5      0.213834
# 6      0.283967
# 7      0.339447
# 8      0.302712
# 9      0.357956
# 10     0.373075
# 11     0.362001
# 12     0.362001
# 13     0.213834
# 14     0.283967
# 15     0.339447
# 16     0.302712
# 17     0.357956
# 18     0.373075
# 19     0.362001
# 20     0.362001
# 21     0.213834
# 22     0.283967
# 23     0.339447
# 24     0.290004
# 25     0.317628
# 26     0.373075
# 27     0.244903
# 28     0.237245
# 29     0.236888
# 30     0.249417
# 31     0.287219

# %%
#ox_spot.drop('Unnamed: 0_x',axis='columns', inplace=True)
#ox_spot.drop('Unnamed: 0_y',axis='columns', inplace=True)

# %%
ox_spot
# Out:
#      CountryName Year_Month  PolicyValue  Happy Index
# 0         Brazil    2020-02     0.000000     0.302712
# 1         Brazil    2020-03     1.000000     0.357956
# 2         Brazil    2020-04     1.000000     0.373075
# 3         Brazil    2020-05     1.838710     0.362001
# 4         Brazil    2020-06     2.000000     0.362001
# 5         Brazil    2020-07     2.000000     0.213834
# 6         Brazil    2020-08     2.225806     0.283967
# 7         Brazil    2020-09     0.000000     0.339447
# 8          Italy    2020-02     0.413793     0.302712
# 9          Italy    2020-03     2.225806     0.357956
# 10         Italy    2020-04     2.300000     0.373075
# 11         Italy    2020-05     2.000000     0.362001
# 12         Italy    2020-06     0.866667     0.362001
# 13         Italy    2020-07     0.000000     0.213834
# 14         Italy    2020-08     0.000000     0.283967
# 15         Italy    2020-09     0.000000     0.339447
# 16  South Africa    2020-02     0.000000     0.302712
# 17  South Africa    2020-03     0.322581     0.357956
# 18  South Africa    2020-04     2.000000     0.373075
# 19  South Africa    2020-05     2.000000     0.362001
# 20  South Africa    2020-06     1.000000     0.362001
# 21  South Africa    2020-07     1.580645     0.213834
# 22  South Africa    2020-08     0.000000     0.283967
# 23  South Africa    2020-09     0.000000     0.339447
# 24           USA    2020-02     0.000000     0.290004
# 25           USA    2020-03     1.032258     0.317628
# 26           USA    2020-04     2.000000     0.373075
# 27           USA    2020-05     2.000000     0.244903
# 28           USA    2020-06     2.000000     0.237245
# 29           USA    2020-07     1.612903     0.236888
# 30           USA    2020-08     1.000000     0.249417
# 31           USA    2020-09     1.000000     0.287219
